# %% [markdown]
# ### **Laboratorio 3**
# *  Angel Guillermo Peñarredonda Silva
# *   Ingenieria en sistemas y computación
# *   Metodos Numericos 2023-1
#
#
# Perfil de LinkedIn: linkedin.com/in/angel-guillermo-silva-b0a008208
#
# Captura de los cursos finalizados:
# ![apenarredondacognitiveclassaapplieddatadciencewithpython.jpeg](data:image/jpeg;base64,...)
#
# # Certificados:
#
# **Python 101 for Data Science:** https://courses.cognitiveclass.ai/certificates/0779b941ba5e4beba4091bb9b5e3c5ff
#
# **Data Analysis with Python:** https://courses.cognitiveclass.ai/certificates/1b2c501f28bf4a8e83255a3da9f42775
#
# **Data Visualization with Python:** https://courses.cognitiveclass.ai/certificates/1a6003194b35435aa2d2c25d4ceadfb4
